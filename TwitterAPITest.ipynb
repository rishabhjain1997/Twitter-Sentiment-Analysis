# %%
import requests
import os
import json

# To set your enviornment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'


def auth():
    import unicodedata
    return(unicodedata.normalize("NFKD", os.environ.get("BEARER_TOKEN")).strip())


def create_url():
    query = "from:narendramodi -is:retweet"
    # Tweet fields are adjustable.
    # Options include:
    # attachments, author_id, context_annotations,
    # conversation_id, created_at, entities, geo, id,
    # in_reply_to_user_id, lang, non_public_metrics, organic_metrics,
    # possibly_sensitive, promoted_metrics, public_metrics, referenced_tweets,
    # source, text, and withheld
    tweet_fields = "tweet.fields=author_id"
    url = "https://api.twitter.com/2/tweets/search/recent?query={}&{}".format(
        query, tweet_fields
    )
    return url


def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers


def connect_to_endpoint(url, headers):
    response = requests.request("GET", url, headers=headers)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()


def main():
    bearer_token = auth()
    url = create_url()
    headers = create_headers(bearer_token)
    json_response = connect_to_endpoint(url, headers)
    print(json.dumps(json_response, indent=4, sort_keys=True))


if __name__ == "__main__":
    main()
# Out:
# 200
# {
#     "data": [
#         {
#             "author_id": "18839785",
#             "id": "1340869821991284738",
#             "text": "Addressing the Indo-Japan Samwad conference. https://t.co/nsZ60A68Lh"
#         },
#         {
#             "author_id": "18839785",
#             "id": "1340862330188353536",
#             "text": "At 9:30 AM, will be speaking at the 6th Indo-Japan Samwad Conference. This forum has grown immensely over the years, contributing to discourses around furthering global peace, harmony and brotherhood."
#         },
#         {
#             "author_id": "18839785",
#             "id": "1340838874642169856",
#             "text": "Birthday greetings to Andhra Pradesh CM Shri @ysjagan Garu. I pray that Almighty blesses him with a healthy and long life."
#         },
#         {
#             "author_id": "18839785",
#             "id": "1340623669207261185",
#             "text": "Best wishes to Uttarakhand CM Shri @tsrawatbjp Ji on his birthday. He is working assiduously for the progress of Uttarakhand. May he be blessed with a long and healthy life."
#         },
#         {
#             "author_id": "18839785",
#             "id": "1340528745824702465",
#             "text": "\u0917\u0941\u0930\u0941 \u0938\u093e\u0939\u093f\u092c \u0915\u0940 \u092f\u0939 \u0935\u093f\u0936\u0947\u0937 \u0915\u0943\u092a\u093e \u0939\u0948 \u0915\u093f \u0939\u092e\u093e\u0930\u0940 \u0938\u0930\u0915\u093e\u0930 \u0915\u0947 \u0915\u093e\u0930\u094d\u092f\u0915\u093e\u0932 \u0915\u0947 \u0926\u094c\u0930\u093e\u0928 \u0939\u0940 \u0939\u092e\u0947\u0902 \u0936\u094d\u0930\u0940 \u0917\u0941\u0930\u0941 \u0924\u0947\u0917 \u092c\u0939\u093e\u0926\u0941\u0930 \u091c\u0940 \u0915\u0947 400\u0935\u0947\u0902 \u092a\u094d\u0930\u0915\u093e\u0936 \u092a\u0930\u094d\u0935 \u0915\u094b \u092e\u0928\u093e\u0928\u0947 \u0915\u093e \u0905\u0935\u0938\u0930 \u092e\u093f\u0932 \u0930\u0939\u093e \u0939\u0948\u0964 \u0906\u0907\u090f, \u0907\u0938 \u092a\u093e\u0935\u0928 \u092e\u094c\u0915\u0947 \u0915\u094b \u0910\u0924\u093f\u0939\u093e\u0938\u093f\u0915 \u092c\u0928\u093e\u090f\u0902 \u0914\u0930 \u0936\u094d\u0930\u0940 \u0917\u0941\u0930\u0941 \u0924\u0947\u0917 \u092c\u0939\u093e\u0926\u0941\u0930 \u091c\u0940 \u0915\u0947  \u0906\u0926\u0930\u094d\u0936\u094b\u0902 \u0915\u094b \u0905\u092a\u0928\u0947 \u091c\u0940\u0935\u0928 \u092e\u0947\u0902 \u0905\u092a\u0928\u093e\u090f\u0902\u0964 https://t.co/fXxVRUU1yI"
#         },
#         {
#             "author_id": "18839785",
#             "id": "1
\u0a26\u0a3e \u0a2e\u0a4c\u0a15\u0a3e \u0a2e\u0a3f\u0a32\u0a3f\u0a06\n\ud83d\ude4f\ud83c\udffb\n\u0a2e\u0a47\u0a30\u0a47 \u0a32\u0a08 \u0a2e\u0a3e\u0a23 \u0a35\u0a3e\u0a32\u0a40 \u0a17\u0a71\u0a32 \u0a39\u0a48 \u0a1c\u0a3f\u0a38 \u0a24\u0a30\u0a4d\u0a39\u0a3e\u0a02 \u0a17\u0a41\u0a30\u0a42 \u0a28\u0a3e\u0a28\u0a15 \u0a26\u0a47\u0a35 \u0a1c\u0a40 \u0a26\u0a3e 550 \u0a38\u0a3e\u0a32\u0a3e\u0a02 \u0a2a\u0a4d\u0a30\u0a15\u0a3e\u0a38\u0a3c \u0a2a\u0a41\u0a30\u0a2c \u0a2e\u0a28\u0a3e\u0a07\u0a06; \u0a09\u0a38\u0a47 \u0a24\u0a30\u0a4d\u0a39\u0a3e\u0a02 \u0a39\u0a41\u0a23 \u0a17\u0a41\u0a30\u0a42 \u0a24\u0a47\u0a17 \u0a2c\u0a39\u0a3e\u0a26\u0a30 \u0a38\u0a3e\u0a39\u0a3f\u0a2c \u0a1c\u0a40 \u0a26\u0a47 400 \u0a38\u0a3e\u0a32\u0a3e\u0a02 \u0a2a\u0a4d\u0a30\u0a15\u0a3e\u0a38\u0a3c \u0a2a\u0a41\u0a30\u0a2c \u0a26\u0a47 \u0a38\u0a2e\u0a3e\u0a17\u0a2e\u0a3e\u0a02 \u0a26\u0a40 \u0a38\u0a47\u0a35\u0a3e \u0a35\u0a40 \u0a2e\u0a47\u0a30\u0a47 \u0a39\u0a3f\u0a71\u0a38\u0a47 \u0a06\u0a08 \u0a39\u0a48 https://t.co/yxyiwGHWVe"
#         }
#     ],
#     "meta": {
#         "newest_id": "1340869821991284738",
#         "next_token": "b26v89c19zqg8o3foshrow0kwpze4ba44vaqblgfbd859",
#         "oldest_id": "1340509954617221121",
#         "result_count": 10
#     }
# }

# %%
import requests
import os
import json
import twitter_credentials
import tweepy
# To set your enviornment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'


def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers


def get_rules(headers, bearer_token):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream/rules", headers=headers
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot get rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))
    return response.json()


def delete_all_rules(headers, bearer_token, rules):
    if rules is None or "data" not in rules:
        return None

    ids = list(map(lambda rule: rule["id"], rules["data"]))
    payload = {"delete": {"ids": ids}}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        headers=headers,
        json=payload
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot delete rules (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    print(json.dumps(response.json()))


def set_rules(headers, delete, bearer_token):
    # You can adjust the rules if needed
    sample_rules = [
        {"value": "dog has:images", "tag": "dog pictures"},
        {"value": "cat has:images -grumpy", "tag": "cat pictures"},
    ]
    payload = {"add": sample_rules}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        headers=headers,
        json=payload,
    )
    if response.status_code != 201:
        raise Exception(
            "Cannot add rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))


def get_stream(headers, set, bearer_token):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream", headers=headers, stream=True,
    )
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Cannot get stream (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    for response_line in response.iter_lines():
        if response_line:
            json_response = json.loads(response_line)
            print(json.dumps(json_response, indent=4, sort_keys=True))


def main():
    bearer_token = twitter_credentials.BEARER_TOKEN
    headers = create_headers(bearer_token)
    rules = get_rules(headers, bearer_token)
    delete = delete_all_rules(headers, bearer_token, rules)
    set = set_rules(headers, delete, bearer_token)
    get_stream(headers, set, bearer_token)


if __name__ == "__main__":
    main()
# Out:
# {"meta": {"sent": "2020-12-21T07:07:06.136Z"}}
# {"data": [{"value": "cat has:images -grumpy", "tag": "cat pictures", "id": "1340916690897391618"}, {"value": "dog has:images", "tag": "dog pictures", "id": "1340916690897391619"}], "meta": {"sent": "2020-12-21T07:07:06.820Z", "summary": {"created": 2, "not_created": 0, "valid": 2, "invalid": 0}}}
# 200
# {
#     "data": {
#         "id": "1340916651965829121",
#         "text": "RT @TyCHEMariasndi: \ud83d\udc9cAmilige\ud83d\udc9c\n\n\ud83c\udf80\u75c5\u307f\u30ab\u30efBLACK\u30b3\u30fc\u30c7\ud83c\udf80\n\u25b6\ufe0eKey Bear\u7dcf\u67c4\u30b9\u30ab\u30fc\u30c8\n\u25b6\ufe0eStrawberry Cat T\u30b7\u30e3\u30c4\n\u25b6\ufe0e\u30a2\u30af\u30bb\u30f3\u30c8\u523a\u7e4d\u30bb\u30fc\u30e9\u30fc\u30d6\u30eb\u30be\u30f3\n\n\u4eba\u6c17\u306e\u30ec\u30c3\u30b0\u30a6\u30a9\u30fc\u30de\u30fc\u306f\u30d1\u30fc\u30d7\u30eb\u3068\u30ec\u30c3\u30c9\u304c\u5b8c\u58f2\u4e2d\ud83d\udca6\n\u305d\u306e\u4ed6\u306e\u30ab\u30e9\u30fc\u30821\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916655820554248",
#         "text": "RT @namtan_0327: Cat and Mona Lisa pic? Mentor Lisa? \ud83e\uddd0\ud83e\uddd0\ud83e\uddd0 https://t.co/kKaRisrtYi"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916658328666112",
#         "text": "RT @nicahls: jujutsu cat-sen https://t.co/XSUjfMOu17"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916658135851008",
#         "text": "RT @AshoryImpex: Manufacturer and exporter of cordura Jackets, Pants, vests,Softshell jackets, pants, vests,bomber jacketsDog training suit\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391619,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916659675045888",
#         "text": "RT @animatesendai: \u3010\ud83c\udf6a#\u30b0\u30e9\u30c3\u30c6\u2615\u3011\n11/20\u304b\u3089\u300e\u3046\u305f\u306e\u2606\u30d7\u30ea\u30f3\u30b9\u3055\u307e\u3063\u266a PRINCE CAT\u00d7Gratte\u300f\u5927\u597d\u8a55\u958b\u50ac\u4e2d\u307f\u3084\u3063\u30c6\u2763\u2763\n\n\u300ePRINCE CAT\u300f\u5bfe\u8c61\u5546\u54c1\u8cfc\u5165\u3001\u3054\u98f2\u98df2,000\u5186\u6bce\u306b\u3010\u30b3\u30fc\u30b9\u30bf\u30fc\uff08\u516811\u7a2e\u304b\u3089\u30e9\u30f3\u30c0\u30e0\uff09\u3011\u304a\u6e21\u3057\ud83c\udfb6\n\n\u30ab\u30d5\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916660241395712",
#         "text": "RT @BlackSupremeKai: Cat owners...\n\nY\u2019all to the cat: GET DOWN!!!!\n\nThe cat: https://t.co/GtLZLCbamz"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916662346911745",
#         "text": "RT @Nikhio_: Dabi with his cat \u2728\n.\n.\n.\n. \n#dabi #touya #touyatodoroki #dabihawks #hawksdabi #hawks https://t.co/MdvQOTmlA0"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916665094029312",
#         "text": "RT @hinako_sara: \uff11\u679a\u76ee  \u30d1\u30d1\u306b\u6012\u3089\u308c\u305f\u6642\n\uff12\u679a\u76ee  \u30de\u30de\u306b\u6012\u3089\u308c\u305f\u6642\u2026\n\n\u3053\u306e\u5dee\u306f\u4f55\u2049\ufe0f\n\n#cat #\u732b\u306e\u3044\u308b\u66ae\u3089\u3057 #\u732b\u3042\u308b\u3042\u308b #\u767d\u732b https://t.co/muI3PbzgXJ"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916668055384065",
#         "text": "RT @AshoryImpex: Manufacturer and exporter of cordura Jackets, Pants, vests,Softshell jackets, pants, vests,bomber jacketsDog training suit\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391619,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916670580236288",
#         "text": "RT @cyanblink: The new Youth With You Season 3 teaser poster features the Mona Lisa and a cat.. Mentor Lisa is coming! \ud83d\udc40 @blackpink https:/\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916672509702146",
#         "text": "RT @rescuemeanimal: Little Big is DEAF so needs a very special INDOOR home &amp; another cat or dog to play with as he loves wrestling #CatsOfT\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391619,
#             "tag": "dog pictures"
#         },
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916672799141888",
#         "text": "RT @tws_pk: We said goodbye to a great friend this past week, our gentle giant Hugo. Hugo was rescued when found being dragged tied to a ve\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391619,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916684463493122",
#         "text": "RT @AshoryImpex: Manufacturer and exporter of cordura Jackets, Pants, vests,Softshell jackets, pants, vests,bomber jacketsDog training suit\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391619,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340

#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916709058727937",
#         "text": "RT @BlackSupremeKai: Cat owners...\n\nY\u2019all to the cat: GET DOWN!!!!\n\nThe cat: https://t.co/GtLZLCbamz"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916708819779585",
#         "text": "RT @stellaris_22: 201220 neowahamgaenyang Instagram Update @RBW_MAMAMOO \n\nMoonbyul adopted a new dog named Harang \ud83e\udd70\n\nhttps://t.co/pVuI75NhG\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391619,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916711613194242",
#         "text": "RT @BlackSupremeKai: Cat owners...\n\nY\u2019all to the cat: GET DOWN!!!!\n\nThe cat: https://t.co/GtLZLCbamz"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916716176617472",
#         "text": "Ohhh to have a cat like Jiji I wish https://t.co/TksDwbNEQh"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916723172651008",
#         "text": "RT @ChrisGPackham: That\u2019s a full 1 metre skid mark on a new carpet . Actually quite impressive . And in the parlance of @vizcomic . . . \u2018Ca\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391619,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916722862153729",
#         "text": "\u2728\u9031\u9593\u30e9\u30f3\u30ad\u30f3\u30b0\u2728\n\n\ud83d\udc51\u540c\u73871\u4f4d\ud83d\udc51\n\n\u3077\u30fc\u3068\u3093 \u30de\u30b9\u30b3\u30c3\u30c8 \u30c7\u30cb\u30e0\n\u30d7\u30e9\u30c3\u30b7\u30e5\u30b3\u30b9\u30c1\u30e5\u30fc\u30de\u30fc\n \u30fb\u3046\u3057L\u30b5\u30a4\u30ba\n\u30fbXmasM\u30b5\u30a4\u30ba\nchoo choo cat \n\u30fb\u30de\u30b9\u30b3\u30c3\u30c8 \u30ec\u30aa\u30d1\u30fc\u30c9\u305a\u304d\u3093\n\n#nipopo #\u3089\u3089\u307d\u30fc\u3068\u540d\u53e4\u5c4b\u307f\u306a\u3068\u30a2\u30af\u30eb\u30b9 #\u9031\u9593\u30e9\u30f3\u30ad\u30f3\u30b0 #\u3077\u30fc\u3068\u3093 #\u30d7\u30e9\u30c3\u30b7\u30e5\u30b3\u30b9\u30c1\u30e5\u30fc\u30de\u30fc #choochoocat https://t.co/naKKTugAkE"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916726528151554",
#         "text": "RT @EnbicixBCN: Ja pedalem pel carrer d\u2019Arag\u00f3\nT'ho expliquem al web \ud83d\udeb2\ud83d\udc47 #biciBCN  https://t.co/THgKPgNiSL https://t.co/gwIRD6TY48"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916728772009984",
#         "text": "RT @ppamm16: ; cat walk\ud83d\udc08\ud83d\udc9b.~\n.\n#\u0e2a\u0e15\u0e39\u0e14\u0e34\u0e42\u0e2d\u0e1e\u0e1e #ONGSEONGWU https://t.co/XJDMwGjnz3"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916728671383552",
#         "text": "RT @AssembSmallorcA: DIADA DE MALLORCA 2020\n\ud83d\udca1 Ja la tenim aqu\u00ed! La cadena humana de la #DiadaDeMallorca 2020 ja admet inscripcions.\n\ud83d\udce2 Dia 2\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916731179638786",
#         "text": "RT @insanerainmusic: Looker is not quite a piano-playing dog... yet... https://t.co/PyMpYKqzbW"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391619,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916734648324097",
#         "text": "12 pack of Rachael Ray Cat Food, as low as $6!\n\nhttps://t.co/stNeFisjO2 https://t.co/9PXsomZh06"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916737148116992",
#         "text": "RT @ryucloudx: I just think about the cat ears and maid dress combo \u263a\ufe0f\n\n#kageyama #haikyuu #haikyuufanart https://t.co/99UQkN1tC1"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916738213507072",
#         "text": "RT @AshoryImpex: Manufacturer and exporter of cordura Jackets, Pants, vests,Softshell jackets, pants, vests,bomber jacketsDog training suit\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391619,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916738888663041",
#         "text": "RT @arifaajakia: A domestic worker (kaam waali baai), a child girl, cannot sit in car with master\u2019s family so has to sit with dog in boot.\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391619,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916744316137473",
#         "text": "RT @nicahls: jujutsu cat-sen https://t.co/XSUjfMOu17"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916747600183297",
#         "text": "RT @soompi: WATCH: #StrayKids' #Hyunjin Releases Beautiful Self-Composed Song Dedicated To His Late Dog https://t.co/cRVtpxYEzC https://t.c\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391619,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916748963364865",
#         "text": "RT @nypost: Budweiser will put your dog on a can of their holiday brew https://t.co/SWdkpPkcir https://t.co/3HU926KcWU"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391619,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916753212293120",
#         "text": "RT @byulsdiamond: no but seriously Moonbyul adopted an almost senior, abandoned dog and didn't even post about it or anything. \n\nher heart\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391619,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916756504702976",
#         "text": "RT @helpfindsamson: \u00a35000 reward to whoever brings our boy home! #helpus #family #stolen #essex #bbc @essexradio @FINDMISSINGDOGS @BBCNews\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391619,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916757519843328",
#         "text": "12 pack of Rachael Ray Cat Food, as low as $6!\n\n #Deal #ganga\n\n https://t.co/UMaUKMQVoC https://t.co/zkUxX6yBpk"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916766122205184",
#         "text": "RT @nekobu_cat: \u3044\u3044\u6e6f\u3060\u306a\u2668\ufe0f\n#\u732b\u597d\u304d\u3055\u3093\u3068\u7e4b\u304c\u308a\u305f\u3044\n#cat https://t.co/N2Z97sd9WO"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916767581904897",
#         "text": "RT @cyanblink: The new Youth With You Season 3 teaser poster features the Mona Lisa and a cat.. Mentor Lisa is coming! \ud83d\udc40 @blackpink https:/\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1340916769024827392",
#         "text": "RT @junheethinker: [\ud83e\uddf8] finally, a cat with some decency https://t.co/Z8hKApiXkD"
#     },
#     "matching_rules": [
#         {
#             "id": 1340916690897391618,
#             "tag": "cat pictures"
#         }
#     ]
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-7f7036129f06> in <module>
#      91
#      92 if __name__ == "__main__":
# ---> 93     main()
#
# <ipython-input-3-7f7036129f06> in main()
#      87     delete = delete_all_rules(headers, bearer_token, rules)
#      88     set = set_rules(headers, delete, bearer_token)
# ---> 89     get_stream(headers, set, bearer_token)
#      90
#      91
#
# <ipython-input-3-7f7036129f06> in get_stream(headers, set, bearer_token)
#      75             )
#      76         )
# ---> 77     for response_line in response.iter_lines():
#      78         if response_line:
#      79             json_response = json.loads(response_line)
#
# ~/anaconda3/lib/python3.8/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     793         pending = None
#     794
# --> 795         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     796
#     797             if pending is not None:
#
# ~/anaconda3/lib/python3.8/site-packages/requests/models.py in generate()
#     749             if hasattr(self.raw, 'stream'):
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#     753                 except ProtocolError as e:
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     569         """
#     570         if self.chunked and self.supports_chunked_reads():
# --> 571             for line in self.read_chunked(amt, decode_content=decode_content):
#     572                 yield line
#     573         else:
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     761
#     762             while True:
# --> 763                 self._update_chunk_length()
#     764                 if self.chunk_left == 0:
#     765                     break
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/response.py in _update_chunk_length(self)
#     691         if self.chunk_left is not None:
#     692             return
# --> 693         line = self._fp.fp.readline()
#     694         line = line.split(b";", 1)[0]
#     695         try:
#
# ~/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
os.environ.get("BEARER_TOKEN")
# Out:
# 'AAAAAAAAAAAAAAAAAAAAAINeKwEAAAAAadb8LIRDiJo3jfNx5ALG3oBJMOA%3DsuOrl3mrPSf4tVzpPz99tbMworGFHVGjxcqTgFjUurArpe4Ymq\xa0'
